# %%
# !pip install opendatasets --upgrade
# Out:
# Requirement already up-to-date: opendatasets in /usr/local/lib/python3.7/dist-packages (0.1.11)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from opendatasets) (4.41.1)
# Requirement already satisfied, skipping upgrade: kaggle in /usr/local/lib/python3.7/dist-packages (from opendatasets) (1.5.12)
# Requirement already satisfied, skipping upgrade: click in /usr/local/lib/python3.7/dist-packages (from opendatasets) (7.1.2)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.23.0)
# Requirement already satisfied, skipping upgrade: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.8.1)
# Requirement already satisfied, skipping upgrade: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied, skipping upgrade: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.24.3)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied, skipping upgrade: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2020.12.5)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.10)
# Requirement already satisfied, skipping upgrade: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib
import opendatasets as od

pd.set_option("display.max_columns",None)

# %%
# dataset_url = "https://www.kaggle.com/datasnaek/chess"
# od.download(dataset_url)

# %%
# Using Pandas to create a dataframe
chess_df = pd.read_csv("./chess/games.csv")
chess_df
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 1      l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate
# 3      kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# 0      white           15+2       bourgris          1500                a-00
# 1      black           5+10           a-00          1322           skinnerua
# 2      white           5+10         ischia          1496                a-00
# 3      white           20+0  daniamurashov          1439        adivanov2009
# 4      white           30+3      nik221107          1523        adivanov2009
# ...      ...            ...            ...           ...                 ...
# 20053  white          10+10        belcolt          1691            jamboger
# 20054  black           10+0       jamboger          1233  farrukhasomiddinov
# 20055  white           10+0       jamboger          1219        schaaksmurf3
# 20056  white           10+0   marcodisogno          1360            jamboger
# 20057  black           10+0       jamboger          1235               ffbob
#
#        black_rating                                              moves  \
# 0              1191  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...
# 1              1261  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...
# 2              1500  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...
# 3              1454  d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...
# 4              1469  e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...
# ...             ...                                                ...
# 20053          1220  d4 f5 e3 e6 Nf3 Nf6 Nc3 b6 Be2 Bb7 O-O Be7 Ne5...
# 20054          1196  d4 d6 Bf4 e5 Bg3 Nf6 e3 exd4 exd4 d5 c3 Bd6 Bd...
# 20055          1286  d4 d5 Bf4 Nc6 e3 Nf6 c3 e6 Nf3 Be7 Bd3 O-O Nbd...
# 20056          1227  e4 d6 d4 Nf6 e5 dxe5 dxe5 Qxd1+ Kxd1 Nd5 c4 Nb...
# 20057          1339  d4 d5 Bf4 Na6 e3 e6 c3 Nf6 Nf3 Bd7 Nbd2 b5 Bd3...
#
#       opening_eco                            opening_name  opening_ply
# 0             D10        Slav Defense: Exchange Variation            5
# 1             B00  Nimzowitsch Defense: Kennedy Variation            4
# 2             C20   King's Pawn Game: Leonardis Variation            3
# 3             D02  Queen's Pawn Game: Zukertort Variation            3
# 4             C41                        Philidor Defense            5
# ...           ...                                     ...          ...
# 20053         A80                           Dutch Defense            2
# 20054         A41                            Queen's Pawn            2
# 20055         D00         Queen's Pawn Game: Mason Attack            3
# 20056         B07                            Pirc Defense            4
# 20057         D00         Queen's Pawn Game: Mason Attack            3
#
# [20058 rows x 16 columns]

# %%
chess_df.head()
# Out:
#          id  rated    created_at  last_move_at  turns victory_status winner  \
# 0  TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1  l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign  black
# 2  mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate  white
# 3  kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate  white
# 4  9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate  white
#
#   increment_code       white_id  white_rating      black_id  black_rating  \
# 0           15+2       bourgris          1500          a-00          1191
# 1           5+10           a-00          1322     skinnerua          1261
# 2           5+10         ischia          1496          a-00          1500
# 3           20+0  daniamurashov          1439  adivanov2009          1454
# 4           30+3      nik221107          1523  adivanov2009          1469
#
#                                                moves opening_eco  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# 2  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...         C20
# 3  d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...         D02
# 4  e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...         C41
#
#                              opening_name  opening_ply
# 0        Slav Defense: Exchange Variation            5
# 1  Nimzowitsch Defense: Kennedy Variation            4
# 2   King's Pawn Game: Leonardis Variation            3
# 3  Queen's Pawn Game: Zukertort Variation            3
# 4                        Philidor Defense            5

# %%
chess_df.shape
# Out:
# (20058, 16)

# %%
chess_df.columns
# Out:
# Index(['id', 'rated', 'created_at', 'last_move_at', 'turns', 'victory_status',
#        'winner', 'increment_code', 'white_id', 'white_rating', 'black_id',
#        'black_rating', 'moves', 'opening_eco', 'opening_name', 'opening_ply'],
#       dtype='object')

# %%
chess_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              20058 non-null  object
#  1   rated           20058 non-null  bool
#  2   created_at      20058 non-null  float64
#  3   last_move_at    20058 non-null  float64
#  4   turns           20058 non-null  int64
#  5   victory_status  20058 non-null  object
#  6   winner          20058 non-null  object
#  7   increment_code  20058 non-null  object
#  8   white_id        20058 non-null  object
#  9   white_rating    20058 non-null  int64
#  10  black_id        20058 non-null  object
#  11  black_rating    20058 non-null  int64
#  12  moves           20058 non-null  object
#  13  opening_eco     20058 non-null  object
#  14  opening_name    20058 non-null  object
#  15  opening_ply     20058 non-null  int64
# dtypes: bool(1), float64(2), int64(4), object(9)
# memory usage: 2.3+ MB

# %%
chess_df.isnull().sum()
# Out:
# id                0
# rated             0
# created_at        0
# last_move_at      0
# turns             0
# victory_status    0
# winner            0
# increment_code    0
# white_id          0
# white_rating      0
# black_id          0
# black_rating      0
# moves             0
# opening_eco       0
# opening_name      0
# opening_ply       0
# dtype: int64

# %%
chess_df.drop(columns=['id','white_id','black_id'],inplace=True)

# %%
chess_df.head()
# Out:
#    rated    created_at  last_move_at  turns victory_status winner  \
# 0  False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1   True  1.504130e+12  1.504130e+12     16         resign  black
# 2   True  1.504130e+12  1.504130e+12     61           mate  white
# 3   True  1.504110e+12  1.504110e+12     61           mate  white
# 4   True  1.504030e+12  1.504030e+12     95           mate  white
#
#   increment_code  white_rating  black_rating  \
# 0           15+2          1500          1191
# 1           5+10          1322          1261
# 2           5+10          1496          1500
# 3           20+0          1439          1454
# 4           30+3          1523          1469
#
#                                                moves opening_eco  \
# 0  d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# 1  d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# 2  e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...         C20
# 3  d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...         D02
# 4  e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...         C41
#
#                              opening_name  opening_ply
# 0        Slav Defense: Exchange Variation            5
# 1  Nimzowitsch Defense: Kennedy Variation            4
# 2   King's Pawn Game: Leonardis Variation            3
# 3  Queen's Pawn Game: Zukertort Variation            3
# 4                        Philidor Defense            5

# %%
chess_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rated           20058 non-null  bool
#  1   created_at      20058 non-null  float64
#  2   last_move_at    20058 non-null  float64
#  3   turns           20058 non-null  int64
#  4   victory_status  20058 non-null  object
#  5   winner          20058 non-null  object
#  6   increment_code  20058 non-null  object
#  7   white_rating    20058 non-null  int64
#  8   black_rating    20058 non-null  int64
#  9   moves           20058 non-null  object
#  10  opening_eco     20058 non-null  object
#  11  opening_name    20058 non-null  object
#  12  opening_ply     20058 non-null  int64
# dtypes: bool(1), float64(2), int64(4), object(6)
# memory usage: 1.9+ MB

# %%
chess_df['victory_status']=chess_df['victory_status'].astype('category')
chess_df['winner']=chess_df['winner'].astype('category')
chess_df['rated']=chess_df['rated'].astype('category')

# %%
chess_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rated           20058 non-null  category
#  1   created_at      20058 non-null  float64
#  2   last_move_at    20058 non-null  float64
#  3   turns           20058 non-null  int64
#  4   victory_status  20058 non-null  category
#  5   winner          20058 non-null  category
#  6   increment_code  20058 non-null  object
#  7   white_rating    20058 non-null  int64
#  8   black_rating    20058 non-null  int64
#  9   moves           20058 non-null  object
#  10  opening_eco     20058 non-null  object
#  11  opening_name    20058 non-null  object
#  12  opening_ply     20058 non-null  int64
# dtypes: category(3), float64(2), int64(4), object(4)
# memory usage: 1.6+ MB

# %%
chess_df.describe()
# Out:
#          created_at  last_move_at         turns  white_rating  black_rating  \
# count  2.005800e+04  2.005800e+04  20058.000000  20058.000000  20058.000000
# mean   1.483617e+12  1.483618e+12     60.465999   1596.631868   1588.831987
# std    2.850151e+10  2.850140e+10     33.570585    291.253376    291.036126
# min    1.376772e+12  1.376772e+12      1.000000    784.000000    789.000000
# 25%    1.477548e+12  1.477548e+12     37.000000   1398.000000   1391.000000
# 50%    1.496010e+12  1.496010e+12     55.000000   1567.000000   1562.000000
# 75%    1.503170e+12  1.503170e+12     79.000000   1793.000000   1784.000000
# max    1.504493e+12  1.504494e+12    349.000000   2700.000000   2723.000000
#
#         opening_ply
# count  20058.000000
# mean       4.816981
# std        2.797152
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max       28.000000

# %%
# # Dropping columns that are of no use for this project
# # The "moves" column will also be dropped because we already have the opening name
# chess_df.drop(["id", "created_at","last_move_at", "white_id", "black_id", "moves", "opening_eco", "opening_ply"], inplace=True, axis=1)

# Renaming increment_code to time_control
chess_df.rename(columns = {"increment_code":"time_control"}, inplace = True)

# %%
chess_df
# Out:
#        rated    created_at  last_move_at  turns victory_status winner  \
# 0      False  1.504210e+12  1.504210e+12     13      outoftime  white
# 1       True  1.504130e+12  1.504130e+12     16         resign  black
# 2       True  1.504130e+12  1.504130e+12     61           mate  white
# 3       True  1.504110e+12  1.504110e+12     61           mate  white
# 4       True  1.504030e+12  1.504030e+12     95           mate  white
# ...      ...           ...           ...    ...            ...    ...
# 20053   True  1.499791e+12  1.499791e+12     24         resign  white
# 20054   True  1.499698e+12  1.499699e+12     82           mate  black
# 20055   True  1.499698e+12  1.499698e+12     35           mate  white
# 20056   True  1.499696e+12  1.499697e+12    109         resign  white
# 20057   True  1.499643e+12  1.499644e+12     78           mate  black
#
#       time_control  white_rating  black_rating  \
# 0             15+2          1500          1191
# 1             5+10          1322          1261
# 2             5+10          1496          1500
# 3             20+0          1439          1454
# 4             30+3          1523          1469
# ...            ...           ...           ...
# 20053        10+10          1691          1220
# 20054         10+0          1233          1196
# 20055         10+0          1219          1286
# 20056         10+0          1360          1227
# 20057         10+0          1235          1339
#
#                                                    moves opening_eco  \
# 0      d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# 1      d4 Nc6 e4 e5 f4 f6 dxe5 fxe5 fxe5 Nxe5 Qd4 Nc6...         B00
# 2      e4 e5 d3 d6 Be3 c6 Be2 b5 Nd2 a5 a4 c5 axb5 Nc...         C20
# 3      d4 d5 Nf3 Bf5 Nc3 Nf6 Bf4 Ng4 e3 Nc6 Be2 Qd7 O...         D02
# 4      e4 e5 Nf3 d6 d4 Nc6 d5 Nb4 a3 Na6 Nc3 Be7 b4 N...         C41
# ...                                                  ...         ...
# 20053  d4 f5 e3 e6 Nf3 Nf6 Nc3 b6 Be2 Bb7 O-O Be7 Ne5...         A80
# 20054  d4 d6 Bf4 e5 Bg3 Nf6 e3 exd4 exd4 d5 c3 Bd6 Bd...         A41
# 20055  d4 d5 Bf4 Nc6 e3 Nf6 c3 e6 Nf3 Be7 Bd3 O-O Nbd...         D00
# 20056  e4 d6 d4 Nf6 e5 dxe5 dxe5 Qxd1+ Kxd1 Nd5 c4 Nb...         B07
# 20057  d4 d5 Bf4 Na6 e3 e6 c3 Nf6 Nf3 Bd7 Nbd2 b5 Bd3...         D00
#
#                                  opening_name  opening_ply
# 0            Slav Defense: Exchange Variation            5
# 1      Nimzowitsch Defense: Kennedy Variation            4
# 2       King's Pawn Game: Leonardis Variation            3
# 3      Queen's Pawn Game: Zukertort Variation            3
# 4                            Philidor Defense            5
# ...                                       ...          ...
# 20053                           Dutch Defense            2
# 20054                            Queen's Pawn            2
# 20055         Queen's Pawn Game: Mason Attack            3
# 20056                            Pirc Defense            4
# 20057         Queen's Pawn Game: Mason Attack            3
#
# [20058 rows x 13 columns]

# %%
chess_df['winner'].value_counts()
# Out:
# white    10001
# black     9107
# draw       950
# Name: winner, dtype: int64

# %%
sns.barplot(x='winner',y='created_at',data=chess_df)

# %%
sns.barplot(x='winner',y='last_move_at',data=chess_df)

# %%
sns.barplot(x='winner',y='opening_ply',data=chess_df)

# %%
chess_df=chess_df[['rated', 'turns', 'victory_status',
       'winner', 'time_control', 'white_rating',
       'black_rating','opening_name']]
chess_df.head()
# Out:
#    rated  turns victory_status winner time_control  white_rating  \
# 0  False     13      outoftime  white         15+2          1500
# 1   True     16         resign  black         5+10          1322
# 2   True     61           mate  white         5+10          1496
# 3   True     61           mate  white         20+0          1439
# 4   True     95           mate  white         30+3          1523
#
#    black_rating                            opening_name
# 0          1191        Slav Defense: Exchange Variation
# 1          1261  Nimzowitsch Defense: Kennedy Variation
# 2          1500   King's Pawn Game: Leonardis Variation
# 3          1454  Queen's Pawn Game: Zukertort Variation
# 4          1469                        Philidor Defense

# %%
chess_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20058 entries, 0 to 20057
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   rated           20058 non-null  category
#  1   turns           20058 non-null  int64
#  2   victory_status  20058 non-null  category
#  3   winner          20058 non-null  category
#  4   time_control    20058 non-null  object
#  5   white_rating    20058 non-null  int64
#  6   black_rating    20058 non-null  int64
#  7   opening_name    20058 non-null  object
# dtypes: category(3), int64(3), object(2)
# memory usage: 842.8+ KB

# %%
# Univariate Analysis

# Let's start with the winner col

sns.countplot(chess_df['winner'])

white_win=round((chess_df['winner'].value_counts().values[0]/20058)*100)
black_win=round((chess_df['winner'].value_counts().values[1]/20058)*100)
draw=round((chess_df['winner'].value_counts().values[2]/20058)*100)


print("Out of 20058 {} % chances that white win the match".format(white_win))
print("Out of 20058 {} % chances that black win the match".format(black_win))
print("Out of 20058 {} % chances that match will draw".format(draw))
# Out:
# Out of 20058 50 % chances that white win the match
# Out of 20058 45 % chances that black win the match
# Out of 20058 5 % chances that match will draw
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
chess_df['victory_status'].value_counts()
# Out:
# resign       11147
# mate          6325
# outoftime     1680
# draw           906
# Name: victory_status, dtype: int64

# %%
# created_at col

print((chess_df['victory_status'].value_counts()/20058)*100)

sns.countplot(chess_df['victory_status'])
# Out:
# resign       55.573836
# mate         31.533553
# outoftime     8.375710
# draw          4.516901
# Name: victory_status, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# rated col

print((chess_df['rated'].value_counts()/20058)*100)

sns.countplot(chess_df['rated'])
# Out:
# True     80.54143
# False    19.45857
# Name: rated, dtype: float64
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# created_at column

sns.distplot(chess_df['turns'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(chess_df['turns'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
print("Game with turns between 250 and 350",chess_df[(chess_df['turns']>250) & (chess_df['turns']<350)].shape[0])
print("Game with turns between 150 and 250",chess_df[(chess_df['turns']>150) & (chess_df['turns']<250)].shape[0])
print("Game with turns between 0 and 150",chess_df[(chess_df['turns']>0) & (chess_df['turns']<150)].shape[0])
# Out:
# Game with turns between 250 and 350 4
# Game with turns between 150 and 250 285
# Game with turns between 0 and 150 19747

# %%
# white_rating column

sns.distplot(chess_df['white_rating'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(chess_df['white_rating'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# black_rating column

sns.distplot(chess_df['black_rating'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(chess_df['black_rating'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Multivariate Analysis

# Winner with rated

sns.countplot(chess_df['winner'], hue=chess_df['rated'])

pd.crosstab(chess_df['rated'], chess_df['winner']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# winner  black  draw  white
# rated
# False    44.1   5.9   49.9
# True     45.7   4.5   49.8

# %%
# Winner with victory_status

sns.countplot(chess_df['winner'], hue=chess_df['victory_status'])

pd.crosstab(chess_df['victory_status'], chess_df['winner']).apply(lambda r: round((r/r.sum())*100,1), axis=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# winner          black   draw  white
# victory_status
# draw              0.0  100.0    0.0
# mate             47.1    0.0   52.9
# outoftime        49.0    2.6   48.4
# resign           47.6    0.0   52.4

# %%
# Winner with turns         

plt.figure(figsize=(15,6))
sns.distplot(chess_df[chess_df['winner']=='white']['turns'])
sns.distplot(chess_df[chess_df['winner']=='black']['turns'])
sns.distplot(chess_df[chess_df['winner']=='draw']['turns'])
plt.legend(["White", "Black","Draw"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
 # Winner with white_rating         


plt.figure(figsize=(15,6))
sns.distplot(chess_df[chess_df['winner']=='white']['white_rating'])
sns.distplot(chess_df[chess_df['winner']=='black']['white_rating'])
sns.distplot(chess_df[chess_df['winner']=='draw']['white_rating'])
plt.legend(["White", "Black","Draw"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
 # Winner with black_rating         

plt.figure(figsize=(15,6))
sns.distplot(chess_df[chess_df['winner']=='white']['black_rating'])
sns.distplot(chess_df[chess_df['winner']=='black']['black_rating'])
sns.distplot(chess_df[chess_df['winner']=='draw']['black_rating'])
plt.legend(["White", "Black","Draw"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(chess_df)

# %%
sns.heatmap(chess_df.corr())

# %%
chess_rated = chess_df.rated == True

# %%
chess_rated
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 20053     True
# 20054     True
# 20055     True
# 20056     True
# 20057     True
# Name: rated, Length: 20058, dtype: bool

# %%
chess_rated_df = chess_df[chess_rated]
chess_rated_df
# Out:
#       rated  turns victory_status winner time_control  white_rating  \
# 1      True     16         resign  black         5+10          1322
# 2      True     61           mate  white         5+10          1496
# 3      True     61           mate  white         20+0          1439
# 4      True     95           mate  white         30+3          1523
# 6      True     33         resign  white         10+0          1520
# ...     ...    ...            ...    ...          ...           ...
# 20053  True     24         resign  white        10+10          1691
# 20054  True     82           mate  black         10+0          1233
# 20055  True     35           mate  white         10+0          1219
# 20056  True    109         resign  white         10+0          1360
# 20057  True     78           mate  black         10+0          1235
#
#        black_rating                                opening_name
# 1              1261      Nimzowitsch Defense: Kennedy Variation
# 2              1500       King's Pawn Game: Leonardis Variation
# 3              1454      Queen's Pawn Game: Zukertort Variation
# 4              1469                            Philidor Defense
# 6              1423  Blackmar-Diemer Gambit: Pietrowsky Defense
# ...             ...                                         ...
# 20053          1220                               Dutch Defense
# 20054          1196                                Queen's Pawn
# 20055          1286             Queen's Pawn Game: Mason Attack
# 20056          1227                                Pirc Defense
# 20057          1339             Queen's Pawn Game: Mason Attack
#
# [16155 rows x 8 columns]

# %%
# Creating variables that contain the amount of rated, unrated, and both types of games using the .shape() method
chess_rated_games = chess_rated_df.shape[0]
chess_rated_and_unrated_games = chess_df.shape[0]
chess_unrated_games = chess_rated_and_unrated_games - chess_rated_games

# %%
# Changing Matplotlib parameters
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
# Creating a colour palette
cmap = plt.get_cmap("tab20c")
outer_colors = cmap(np.arange(6)*4)
inner_colors = cmap(np.array([1, 2, 5, 6, 9,
                              10, 12, 13, 15,
                              17, 18, 20 ]))

# %%
# Plotting a pie chart to set the number of games that are rated vs. unrated
labels = ["Rated", "Unrated"]
variables = [chess_rated_games, chess_unrated_games]

plt.figure(figsize =(14, 5), dpi=100)
plt.title("Rated vs. Unrated games")
plt.pie(variables, labels=labels, autopct='%1.1f%%', colors = inner_colors)
plt.axis('equal')
plt.tight_layout();

# %%
# Plotting the ELO of the players in rated games

plt.figure(figsize =(14, 5), dpi=100)
plt.title("Elo of the players in rated games")
plt.hist([chess_rated_df.white_rating, chess_rated_df.black_rating])
plt.legend(["White rating", "Black Rating"])

# %%
# Grouping values by their opening names, and renaming the column.

chess_rated_openings = chess_rated_df.groupby("opening_name").opening_name.count()
chess_rated_openings_df = chess_rated_openings.to_frame()

chess_rated_openings_df.rename(columns={ chess_rated_openings_df.columns[0]: "number_of_times_played"}, inplace = True)
chess_rated_openings_df
# Out:
#                                         number_of_times_played
# opening_name
# Alekhine Defense                                            38
# Alekhine Defense #2                                          3
# Alekhine Defense #3                                          1
# Alekhine Defense: Balogh Variation                           1
# Alekhine Defense: Brooklyn Variation                         2
# ...                                                        ...
# Zukertort Opening: Sicilian Invitation                      29
# Zukertort Opening: Slav Invitation                           8
# Zukertort Opening: Tennison Gambit                          36
# Zukertort Opening: The Walrus                                1
# Zukertort Opening: Vos Gambit                                3
#
# [1384 rows x 1 columns]

# %%
# Sorting and getting the top 10 most played openings
chess_rated_openings_sorted_df = chess_rated_openings_df.sort_values("number_of_times_played", ascending=False).head(10)
chess_rated_openings_sorted_df
# Out:
#                                                number_of_times_played
# opening_name
# Van't Kruijs Opening                                              308
# Sicilian Defense                                                  283
# Sicilian Defense: Bowdler Attack                                  248
# French Defense: Knight Variation                                  229
# Scotch Game                                                       219
# Scandinavian Defense: Mieses-Kotroc Variation                     207
# Queen's Pawn Game: Mason Attack                                   187
# Scandinavian Defense                                              186
# Horwitz Defense                                                   184
# Queen's Pawn Game: Chigorin Variation                             180

# %%
matplotlib.rcParams['font.size'] = 20
chess_rated_openings_sorted_df.plot(kind="barh", 
                                    legend=False, 
                                    title = "Most used openings in rated games", 
                                    figsize = (16,10), 
                                    xlabel = "", 
                                    fontsize = 14);

# %%
# Grouping values by their time controls, and renaming the column.

chess_rated_time_control = chess_rated_df.groupby("time_control").time_control.count()
chess_rated_time_control_df = chess_rated_time_control.to_frame()
chess_rated_time_control_df

chess_rated_time_control_df.rename(columns={ chess_rated_time_control_df.columns[0]: "number_of_times_played"}, inplace = True)
chess_rated_time_control_df
# Out:
#               number_of_times_played
# time_control
# 0+12                               5
# 0+13                               1
# 0+15                               6
# 0+16                              15
# 0+20                               1
# ...                              ...
# 90+0                               9
# 90+120                             1
# 90+30                             12
# 90+5                               1
# 90+8                               1
#
# [349 rows x 1 columns]

# %%
# Sorting and getting the top 10 most played time controls
chess_rated_time_control_df = chess_rated_time_control_df.sort_values("number_of_times_played", ascending=False).head(10)
chess_rated_time_control_df
# Out:
#               number_of_times_played
# time_control
# 10+0                            6817
# 15+0                             961
# 15+15                            722
# 5+5                              570
# 5+8                              523
# 8+0                              506
# 10+5                             434
# 15+10                            351
# 20+0                             291
# 10+10                            255

# %%
chess_rated_time_control_df.plot(kind="barh", 
                                 legend=False, 
                                 title = "Most used time controls in rated games", 
                                 figsize = (14,5), 
                                 xlabel = "Time control", 
                                 fontsize = 14);

# %%
# Setting the style using sns.set_style to "whitegrid"
sns.set_style("darkgrid")
  
matplotlib.rcParams['font.size'] = 12
plt.figure(figsize =(14, 5), dpi=100)
plt.title('Amount of turns')
plt.hist(chess_rated_df.turns, bins=np.arange(0, 200, 10))
plt.tight_layout();

# %%
chess_rated_df
# Out:
#       rated  turns victory_status winner time_control  white_rating  \
# 1      True     16         resign  black         5+10          1322
# 2      True     61           mate  white         5+10          1496
# 3      True     61           mate  white         20+0          1439
# 4      True     95           mate  white         30+3          1523
# 6      True     33         resign  white         10+0          1520
# ...     ...    ...            ...    ...          ...           ...
# 20053  True     24         resign  white        10+10          1691
# 20054  True     82           mate  black         10+0          1233
# 20055  True     35           mate  white         10+0          1219
# 20056  True    109         resign  white         10+0          1360
# 20057  True     78           mate  black         10+0          1235
#
#        black_rating                                opening_name
# 1              1261      Nimzowitsch Defense: Kennedy Variation
# 2              1500       King's Pawn Game: Leonardis Variation
# 3              1454      Queen's Pawn Game: Zukertort Variation
# 4              1469                            Philidor Defense
# 6              1423  Blackmar-Diemer Gambit: Pietrowsky Defense
# ...             ...                                         ...
# 20053          1220                               Dutch Defense
# 20054          1196                                Queen's Pawn
# 20055          1286             Queen's Pawn Game: Mason Attack
# 20056          1227                                Pirc Defense
# 20057          1339             Queen's Pawn Game: Mason Attack
#
# [16155 rows x 8 columns]

# %%
# Grouping values by the winner, and renaming the column.
chess_rated_winner = chess_rated_df.groupby("winner").winner.count()
chess_rated_winner_df = chess_rated_winner.to_frame()

chess_rated_winner_df.rename(columns={ chess_rated_winner_df.columns[0]: "number_of_times"}, inplace = True)
chess_rated_winner_df
# Out:
#         number_of_times
# winner
# black              7384
# draw                719
# white              8052

# %%
# Setting each win in variables
black_wins = chess_rated_winner_df.number_of_times[0]
white_wins = chess_rated_winner_df.number_of_times[2]
draws = chess_rated_winner_df.number_of_times[1]
total_matches = white_wins + black_wins + draws

# %%
# Plotting a pie chart to set the amount of games that black wins vs. white wins vs. draws
labels = ["Black wins", "White wins", "Draws"]
variables = [black_wins, white_wins, draws]

plt.figure(figsize =(10, 5), dpi=100)
plt.title("Amount of games that black wins vs. white wins vs. draws")
plt.pie(variables, labels=labels, autopct='%1.1f%%', colors = inner_colors)
plt.axis('equal')
plt.tight_layout();

# %%
# Grouping values by how the match ended (victory status)
chess_rated_victory_status = chess_rated_df.groupby("victory_status").victory_status.count()
chess_rated_victory_status_df = chess_rated_victory_status.to_frame()

chess_rated_victory_status_df.rename(columns={ chess_rated_victory_status_df.columns[0]: "number_of_times"}, inplace = True)
chess_rated_victory_status_df
# Out:
#                 number_of_times
# victory_status
# draw                        681
# mate                       5146
# outoftime                  1359
# resign                     8969

# %%
# Setting each of the victory status in variables
draws_victory_status = chess_rated_victory_status_df.number_of_times[0]
mates = chess_rated_victory_status_df.number_of_times[1]
out_of_time = chess_rated_victory_status_df.number_of_times[2]
resign = chess_rated_victory_status_df.number_of_times[3]

# %%
# Plotting a pie chart to set the amount of games that black wins vs. white wins vs. draws
labels = ["Draws", "Mate", "Out of Time", "Resign"]
variables = [draws_victory_status, mates, out_of_time, resign]

plt.figure(figsize =(10, 5), dpi=100)
plt.title("Victory status")
plt.pie(variables, labels=labels, autopct='%1.1f%%', colors = inner_colors)
plt.axis('equal')
plt.tight_layout();
