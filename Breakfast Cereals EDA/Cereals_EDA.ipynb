# %%
#import pandas and matplotlib libraries
import pandas as pd
import matplotlib.pylab as plt 
import seaborn as sns

# %%
#read the csv file
cereals_df=pd.read_csv('/content/drive/MyDrive/dataset/Breakfast_Cereals.csv')
cereals_df.head()
# Out:
#                         name mfr type  calories  ...  shelf  weight  cups     rating
# 0                  100%_Bran   N    C        70  ...      3     1.0  0.33  68.402973
# 1          100%_Natural_Bran   Q    C       120  ...      3     1.0  1.00  33.983679
# 2                   All-Bran   K    C        70  ...      3     1.0  0.33  59.425505
# 3  All-Bran_with_Extra_Fiber   K    C        50  ...      3     1.0  0.50  93.704912
# 4             Almond_Delight   R    C       110  ...      3     1.0  0.75  34.384843
#
# [5 rows x 16 columns]

# %%
cereals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     76 non-null     float64
#  9   sugars    76 non-null     float64
#  10  potass    75 non-null     float64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(7), int64(6), object(3)
# memory usage: 9.8+ KB

# %%
cereals_df.shape
# Out:
# (77, 16)

# %%
cereals_df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       1
# sugars      1
# potass      2
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
cereals_df.nunique()
# Out:
# name        77
# mfr          7
# type         2
# calories    11
# protein      6
# fat          5
# sodium      27
# fiber       13
# carbo       21
# sugars      16
# potass      35
# vitamins     3
# shelf        3
# weight       7
# cups        12
# rating      77
# dtype: int64

# %%
cereals_df.carbo.value_counts()
# Out:
# 13.0    8
# 15.0    8
# 16.0    7
# 14.0    7
# 21.0    7
# 12.0    7
# 17.0    6
# 11.0    5
# 20.0    3
# 18.0    3
# 8.0     2
# 10.0    2
# 22.0    2
# 10.5    2
# 7.0     1
# 9.0     1
# 19.0    1
# 11.5    1
# 13.5    1
# 23.0    1
# 5.0     1
# Name: carbo, dtype: int64

# %%
cereals_df['carbo'].fillna(cereals_df['carbo'].mean(),inplace=True)

# %%
cereals_df['sugars'].fillna(cereals_df['sugars'].mean(),inplace=True)

# %%
cereals_df['potass'].fillna(cereals_df['potass'].mean(),inplace=True)

# %%
cereals_df.isnull().values.any()
# Out:
# False

# %%
cereals_df.isnull().sum()
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %%
cereals_df2=cereals_df.copy()

# %%
discard_columns = ['name','mfr','shelf','weight','cups']

# %%
cereals_df = cereals_df.drop(discard_columns, axis=1)

# %%
cereals_df.head()
# Out:
#   type  calories  protein  fat  ...  sugars      potass  vitamins     rating
# 0    C        70        4    1  ...     6.0  280.000000        25  68.402973
# 1    C       120        3    5  ...     8.0  135.000000         0  33.983679
# 2    C        70        4    1  ...     5.0  320.000000        25  59.425505
# 3    C        50        4    0  ...     0.0  330.000000        25  93.704912
# 4    C       110        2    2  ...     8.0   98.666667        25  34.384843
#
# [5 rows x 11 columns]

# %%
cereals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      77 non-null     object
#  1   calories  77 non-null     int64
#  2   protein   77 non-null     int64
#  3   fat       77 non-null     int64
#  4   sodium    77 non-null     int64
#  5   fiber     77 non-null     float64
#  6   carbo     77 non-null     float64
#  7   sugars    77 non-null     float64
#  8   potass    77 non-null     float64
#  9   vitamins  77 non-null     int64
#  10  rating    77 non-null     float64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 6.7+ KB

# %%
import numpy as np

# %%
x=cereals_df['calories']
y1=cereals_df['protein']
plt.figure(figsize=(12,6))
plt.scatter(x,y1)
plt.xlabel('calories',size=15)
plt.ylabel('protein',size=15)
plt.title('calories vs protein')
# Out:
# Text(0.5, 1.0, 'calories vs protein')

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)
sns.barplot(cereals_df2['mfr'].value_counts().index.values, cereals_df2['mfr'].value_counts().values);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
cereals_df.describe()
# Out:
#          calories    protein        fat  ...      potass    vitamins     rating
# count   77.000000  77.000000  77.000000  ...   77.000000   77.000000  77.000000
# mean   106.883117   2.545455   1.012987  ...   98.666667   28.246753  42.665705
# std     19.484119   1.094790   1.006473  ...   69.478004   22.342523  14.047289
# min     50.000000   1.000000   0.000000  ...   15.000000    0.000000  18.042851
# 25%    100.000000   2.000000   0.000000  ...   45.000000   25.000000  33.174094
# 50%    110.000000   3.000000   1.000000  ...   90.000000   25.000000  40.400208
# 75%    110.000000   3.000000   2.000000  ...  120.000000   25.000000  50.828392
# max    160.000000   6.000000   5.000000  ...  330.000000  100.000000  93.704912
#
# [8 rows x 10 columns]

# %%
fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(18,8))
i=0

#adjust the space between main title and subplots
fig.subplots_adjust(top=0.90)

for row in ax:
    for col in row:
        n=cereals_df.columns[i]
        i=i+1
        plt.subplot(2,5,i)
        plt.hist(cereals_df[n], color='mediumturquoise')
        plt.xlabel(n, fontsize=13)
               
plt.suptitle("Cereals Components Distribution", size=15)   
plt.show()

# %% [markdown]
# Key findings on the components of the cereals:
# - Most of the cereals have between 80 and 125 calories per serving;
# - The majority of the cereals have high sodium values - over 150 milligrams;
# - Fiber amounts are quite low in most of the cereals (0-4 grams);
# -Sugar values are quite spread out among the cereals;
# -Most of cereals have up to 130 milligrams of potassium;
# -The ratings for the cereals range mostly from 25 to 55 scores.

# %%
#compute correlation table to analyze variables relationship
corr=cereals_df.corr().round(2)
corr
# Out:
#           calories  protein   fat  sodium  ...  sugars  potass  vitamins  rating
# calories      1.00     0.02  0.50    0.30  ...    0.57   -0.07      0.27   -0.69
# protein       0.02     1.00  0.21   -0.05  ...   -0.28    0.56      0.01    0.47
# fat           0.50     0.21  1.00   -0.01  ...    0.30    0.20     -0.03   -0.41
# sodium        0.30    -0.05 -0.01    1.00  ...    0.06   -0.04      0.36   -0.40
# fiber        -0.29     0.50  0.02   -0.07  ...   -0.14    0.91     -0.03    0.58
# carbo         0.26    -0.02 -0.30    0.29  ...   -0.47   -0.36      0.22    0.09
# sugars        0.57    -0.28  0.30    0.06  ...    1.00    0.00      0.10   -0.76
# potass       -0.07     0.56  0.20   -0.04  ...    0.00    1.00     -0.01    0.41
# vitamins      0.27     0.01 -0.03    0.36  ...    0.10   -0.01      1.00   -0.24
# rating       -0.69     0.47 -0.41   -0.40  ...   -0.76    0.41     -0.24    1.00
#
# [10 rows x 10 columns]

# %%
#create a heatmap to demonstrate the correlation magnitude among the variables
sns.set(font_scale=1.2)
fig, ax = plt.subplots(figsize=(12,8))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, annot_kws={'fontsize':13},
            fmt=".2f", cmap='PiYG', center=0) #annot argument writes the data value into each cell 
                                                #fmt parameter add text to the heatmap cell and formats the cell values

# %% [markdown]
# **Most strongly correlated variables**
#
# Fiber and potassium are the highest correlated variables. Their coefficient is 0.91, which indicates that it is a strong and positive relationship. It represents that the more fiber a cereal contains, the more potassium it may have, and vice-versa. Another pair of relatively strong correlation is sugar and rating, with a coefficient of -0.76. It means that the more sugar a cereal has, the lower the rating might be.

# %%
#plot a scatterplot of sugars and ratings variables
cereals_df.plot.scatter(x='sugars',y='rating',c='green', figsize=(12,7))
plt.xlabel("Sugars (in grams)")
plt.ylabel("Rating")
plt.title('Sugars Amount vs Rating')
# Out:
# Text(0.5, 1.0, 'Sugars Amount vs Rating')

# %%
#replace values for cereal types
cereals_df['type'] = cereals_df['type'].apply(lambda a: str(a).replace('C', 'Cold').replace('H', 'Hot'))

# %%
#group cereal types using the mean rating
types_df=cereals_df.groupby(['type'])['rating'].mean()
types_df
# Out:
# type
# Cold    42.095218
# Hot     56.737708
# Name: rating, dtype: float64

# %%
sns.distplot(cereals_df['calories'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(cereals_df['calories'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#plot cereal ratings by type 
types_df.plot.barh(x='type', y='rating', 
                           title='Cereals Rating by Type', legend=False, figsize=(12,7), cmap='Paired', grid=False)

# %%
#change the manufacturer names
cereals_df2['mfr'] = cereals_df2['mfr'].apply(lambda a: str(a).replace('A', 'American Home Food')
                                              .replace('G', 'General Mills').replace('K', 'Kellogs')
                                              .replace('N', 'Nabisco').replace('P', 'Post')
                                              .replace('Q', 'Quaker Oats').replace('R','Ralson Purina'))

# %%
print(cereals_df2['mfr'])
# Out:
# 0           Nabisco
# 1       Quaker Oats
# 2           Kellogs
# 3           Kellogs
# 4     Ralson Purina
#           ...
# 72    General Mills
# 73    General Mills
# 74    Ralson Purina
# 75    General Mills
# 76    General Mills
# Name: mfr, Length: 77, dtype: object

# %%
#group cereal manufacturer using the mean rating
manufacturer=cereals_df2.groupby(['mfr'])['rating'].mean()
manufacturer
# Out:
# mfr
# American Home Food    54.850917
# General Mills         34.485852
# Kellogs               44.038462
# Nabisco               67.968567
# Post                  41.705744
# Quaker Oats           42.915990
# Ralson Purina         41.542997
# Name: rating, dtype: float64

# %%
#convert series to dataframe
manufacturer_df = pd.DataFrame(manufacturer)
manufacturer_df
# Out:
#                        rating
# mfr
# American Home Food  54.850917
# General Mills       34.485852
# Kellogs             44.038462
# Nabisco             67.968567
# Post                41.705744
# Quaker Oats         42.915990
# Ralson Purina       41.542997

# %%
manufacturer_df.reset_index('mfr', inplace=True)
manufacturer_df
# Out:
#                   mfr     rating
# 0  American Home Food  54.850917
# 1       General Mills  34.485852
# 2             Kellogs  44.038462
# 3             Nabisco  67.968567
# 4                Post  41.705744
# 5         Quaker Oats  42.915990
# 6       Ralson Purina  41.542997

# %%
#sort the ratings by descending order
manufacturer_df.sort_values('rating', ascending=False, inplace=True)
manufacturer_df
# Out:
#                   mfr     rating
# 3             Nabisco  67.968567
# 0  American Home Food  54.850917
# 2             Kellogs  44.038462
# 5         Quaker Oats  42.915990
# 4                Post  41.705744
# 6       Ralson Purina  41.542997
# 1       General Mills  34.485852

# %%
#plot a bar chart
manufacturer_df.plot.bar(x='mfr', y='rating', 
                           title='Cereals Rating per Manufacturer', legend=False, figsize=(12,7), cmap='viridis', grid=False,)
plt.xticks(rotation=75)
plt.xlabel("Manufacturer")
plt.ylabel("Rating")
# Out:
# Text(0, 0.5, 'Rating')

# %%
plt.figure(figsize=(10,6))

with plt.style.context('ggplot'):
    sns.countplot(x='mfr',hue='shelf',data=cereals_df2)
plt.title('Grouped by mfr and shelf')
# Out:
# Text(0.5, 1.0, 'Grouped by mfr and shelf')

# %%
plt.hist(cereals_df.carbo)

plt.title('Carbohydrates Histogram')
plt.xlabel('Carbohydrates')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
cereals_df2[cereals_df2.mfr=='Quaker Oats']
# Out:
#                   name          mfr type  ...  weight  cups     rating
# 1    100%_Natural_Bran  Quaker Oats    C  ...     1.0  1.00  33.983679
# 10        Cap'n'Crunch  Quaker Oats    C  ...     1.0  0.75  18.042851
# 35    Honey_Graham_Ohs  Quaker Oats    C  ...     1.0  1.00  21.871292
# 41                Life  Quaker Oats    C  ...     1.0  0.67  45.328074
# 54         Puffed_Rice  Quaker Oats    C  ...     0.5  1.00  60.756112
# 55        Puffed_Wheat  Quaker Oats    C  ...     0.5  1.00  63.005645
# 56  Quaker_Oat_Squares  Quaker Oats    C  ...     1.0  0.50  49.511874
# 57      Quaker_Oatmeal  Quaker Oats    H  ...     1.0  0.67  50.828392
#
# [8 rows x 16 columns]

# %%
sns.regplot(x='fat',y='calories',data=cereals_df)
plt.title('Fat vs Calories')
# Out:
# Text(0.5, 1.0, 'Fat vs Calories')

# %%
sns.regplot(x='fat',y='rating',data=cereals_df)
plt.title('Fat vs rating')
# Out:
# Text(0.5, 1.0, 'Fat vs rating')

# %%
plt.figure(figsize =(14, 6), dpi=80)
plt.title("Fat vs rating")
plt.hist([cereals_df.fat, cereals_df.rating])
plt.legend(["fat", "Rating"])

# %%
plt.figure(figsize =(14, 6), dpi=80)
plt.title("calories vs rating")
plt.hist([cereals_df.calories, cereals_df.rating])
plt.legend(["calories", "Rating"])

# %%
sns.pairplot(cereals_df)
